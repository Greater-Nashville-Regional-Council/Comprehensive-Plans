# %%
import docx
from docx.shared import Inches
from docxtpl import DocxTemplate, InlineImage
import sys
import os

# %% [markdown]
# This writes out all of the figures for a place level primary geography comprehensive plan.

# %%
# Create an instance of a word document
doc = docx.Document()

# Add a Title to the document
doc.add_heading('Comprehensive Plan Figures', 0)

#Pop Images Native Size
doc.add_heading('Population', 1)
thelist = ['POP_bar_primarygeo_population_overtime', 'POP_line_primarygeo_historicalpopulation_overtime', 
       'POP_line_primarygeo_historicalpopulationchange_overtime', 'POP_bar_primarygeo_projectedpopulation_overtime', 
       'POP_bar_primarygeo_populationprojectionchange_overtime', 'POP_line_geocomparative_population_overtime', 
       'POP_bar_geocomparative_populationchange_overtime', 'POP_table_geocomparative_population_overtime', 
       'POP_bar_geocomparative_populationprojectionchange_overtime', 'POP_table_geocomparative_populationprojectionandchange_overtime']
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/POP/{}.png'.format(fig))
    with open('../Figures/POP/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Age Images Native Size
doc.add_heading('Age', 1)
thelist = ['AGE_pyramid_primarygeo_populationpyramid_2021', 'AGE_bar_primarygeo_under5_overtime', 'AGE_bar_primarygeo_under18_overtime', 
       'AGE_bar_primarygeo_18to54_overtime', 'AGE_bar_primarygeo_55older_overtime', 'AGE_bar_primarygeo_65older_overtime', 
       'AGE_table_primarygeo_under18breakout_overtime', 'AGE_table_primarygeo_18to54breakout_overtime', 'AGE_table_primarygeo_55olderbreakout_overtime', 
       'AGE_stackedbar_primarygeo_agegroups_overtime', 'AGE_clusterbar_primarygeo_changeingroups_overtime', 'AGE_table_geocomparative_agecomposition_2000', 
       'AGE_table_geocomparative_agecomposition_2010', 'AGE_table_geocomparative_agecomposition_2021', 'AGE_table_geocomparative_changeinagegroups_00to10', 
       'AGE_table_geocomparative_changeinagegroups_10to21', 'AGE_table_geocomparative_changeinagegroups_00to21']
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/AGE/{}.png'.format(fig))
    with open('../Figures/AGE/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Race and Ethnicity Images Native Size
doc.add_heading('Race and Ethnicity', 1)
thelist = ['RACEETH_stackedbar_primarygeo_sharehispanicorlatino_overtime', 'RACEETH_table_primarygeo_hispaniclatinoethnicityandchange_overtime', 
           'RACEETH_stackedbar_primarygeo_minoritystatus_overtime', 'RACEETH_table_primarygeo_minoritystatusandchange_overtime', 
           'RACEETH_clusterbar_geocomparative_percentchangetotalvsminority_overtime', 'RACEETH_table_geocomparative_allchangeminority_overtime', 
           'RACEETH_bar_primarygeo_numberrace_2020', 'RACEETH_table_primarygeo_raceandchange_overtime', 
           'RACEETH_clusterbar_primarygeo_changeinracialgroups_overtime', 'RACEETH_stackedbar_primarygeo_sharenonwhite_overtime', 
           'RACEETH_table_primarygeo_nonwhite_overtime', 'RACEETH_table_geocomparative_percentracegroups_2000', 'RACEETH_table_geocomparative_numberracegroups_2000', 
           'RACEETH_table_geocomparative_percentracegroups_2010', 'RACEETH_table_geocomparative_numberracegroups_2010', 
           'RACEETH_table_geocomparative_percentracegroups_2020', 'RACEETH_table_geocomparative_numberracegroups_2020', 
           'RACEETH_table_geocomparative_percentchangeracegroups_00to10', 'RACEETH_table_geocomparative_realchangeracegroups_00to10', 
           'RACEETH_table_geocomparative_percentchangeracegroups_10to20', 'RACEETH_table_geocomparative_realchangeracegroups_10to20', 
           'RACEETH_table_geocomparative_percentchangeracegroups_00to20', 'RACEETH_table_geocomparative_realchangeracegroups_00to20']
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/RACEETH/{}.png'.format(fig))
    with open('../Figures/RACEETH/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)

#Foreign Born Images Native Size
doc.add_heading('Foreign-Born Population', 1)
thelist = ['FOREIGNBORN_stackedbar_primarygeo_shareforeignandnativeborn_overtime', 'FOREIGNBORN_table_primarygeo_foreignbornstatusandchange_overtime', 
           'FOREIGNBORN_table_primarygeo_foreignbornorigin_overtime', 'FOREIGNBORN_table_geocomparative_percentplaceoforigin_2000', 
           'FOREIGNBORN_table_geocomparative_numberplaceoforigin_2000', 'FOREIGNBORN_table_geocomparative_percentplaceoforigin_2010', 
           'FOREIGNBORN_table_geocomparative_numberplaceoforigin_2010', 'FOREIGNBORN_table_geocomparative_percentplaceoforigin_2021', 
           'FOREIGNBORN_table_geocomparative_numberplaceoforigin_2021', 'FOREIGNBORN_table_geocomparative_allchangeforeignborn_overtime', 
           'FOREIGNBORN_clusterbar_geocomparative_realchangetotalvsforeignborn_overtime', 
           'FOREIGNBORN_clusterbar_geocomparative_percentchangetotalvsforeignborn_overtime', 
           'FOREIGNBORN_stackedbar_primarygeo_sharefbcitizenandnot_overtime', 'FOREIGNBORN_table_primarygeo_citizenshipstatus_overtime']
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/FOREIGNBORN/{}.png'.format(fig))
    with open('../Figures/FOREIGNBORN/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)    
    
#Language Images Native Size
doc.add_heading('Language', 1)
thelist = ['LANGUAGE_stackedbar_primarygeo_shareenglishornon_overtime', 'LANGUAGE_stackedbar_primarygeo_sharenonenglishlanguages_overtime', 
           'LANGUAGE_table_primarygeo_languagebesidesenglish_2021', 'LANGUAGE_table_primarygeo_languagespokenathome_overtime', 
           'LANGUAGE_bar_primarygeo_englishwellorverywell_2021', 'LANGUAGE_bar_primarygeo_englishnotwelloratall_2021', 
           'LANGUAGE_table_geocomparative_englishornon_overtime']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/LANGUAGE/{}.png'.format(fig))
    with open('../Figures/LANGUAGE/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Poverty Images Native Size
doc.add_heading('Poverty', 1)
thelist = ['POVERTY_bar_primarygeo_populationbelowpovertylevel_overtime', 'POVERTY_bar_primarygeo_percentpopulationbelowpovertylevel_overtime', 
           'POVERTY_bar_geocomparative_povertyrate_2021', 'POVERTY_line_geocomparative_sharebelowpovertylevel_overtime', 
           'POVERTY_table_geocomparative_rateandchange_overtime', 'POVERTY_clusterbar_primarygeo_u18popsharevspovertypopshare_overtime', 
           'POVERTY_clusterbar_primarygeo_18to64popsharevspovertypopshare_overtime', 'POVERTY_clusterbar_primarygeo_65overpopsharevspovertypopshare_overtime', 
           'POVERTY_table_primarygeo_byagegroups_2021', 'POVERTY_clusterbar_primarygeo_raceethpopulationsharevspovertypopulationshare_2021', 
           'POVERTY_table_primarygeo_byraceeth_2021']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/POVERTY/{}.png'.format(fig))
    with open('../Figures/POVERTY/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Income Images Native Size
doc.add_heading('Income', 1)
thelist = ['INCOME_bar_primarygeo_medianhouseholdincome_overtime', 'INCOME_bar_primarygeo_medianhhincomedistribution_2021', 
           'INCOME_table_geocomparative_medianhhincomeandchange_overtime', 'INCOME_bar_geocomparative_changemedianhhincomevsinflation_overtime']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/INCOME/{}.png'.format(fig))
    with open('../Figures/INCOME/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Households Images Native Size
doc.add_heading('Households', 1)
thelist = ['HOUSEHOLDS_bar_primarygeo_avgsize_overtime', 'HOUSEHOLDS_bar_geocomparative_avgsize_2021', 
           'HOUSEHOLDS_line_geocomparative_HUDresidentialpermits_overtime', 'HOUSEHOLDS_stackedbar_geocomparative_HUDresidentialbuildingtypeandmix_2021', 
           'HOUSEHOLDS_table_geocomparative_HUDresidentialpermitperunittype_2021', 'HOUSEHOLDS_stackedbar_primarygeo_type_overtime', 
           'HOUSEHOLDS_stackedbar_geocomparative_type_2021', 'HOUSEHOLDS_table_primarygeo_type_overtime', 'HOUSEHOLDS_bar_primarygeo_ageofhousingstock_2021', 
           'HOUSEHOLDS_table_geocomparative_medianyearbuiltandageforresidentialstructures_2021', 'HOUSEHOLDS_bar_primarygeo_changeinunitsbytype_overtime']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/HOUSEHOLDS/{}.png'.format(fig))
    with open('../Figures/HOUSEHOLDS/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Vacancy Images Native Size
doc.add_heading('Vacancy', 1)
thelist = ['VACANCY_bar_primarygeo_vacantunits_overtime', 'VACANCY_bar_primarygeo_vacancyrate_overtime', 'VACANCY_bar_geocomparative_vacantunits_2020', 
           'VACANCY_bar_geocomparative_vacancyrate_2020', 'VACANCY_table_geocomparative_vacancyratesandchange_overtime']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/VACANCY/{}.png'.format(fig))
    with open('../Figures/VACANCY/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Tenure & Cost Images Native Size
doc.add_heading('Tenure & Cost', 1)
thelist = ['TENURECOST_stackedbar_primarygeo_shareownvsrent_overtime', 'TENURECOST_stackedbar_primarygeo_mortgagestatus_overtime', 
           'TENURECOST_bar_geocomparative_homeownershiprate_2021', 'TENURECOST_clusterbar_geocomparative_homeownershiprate_overtime', 
           'TENURECOST_bar_geocomparative_rentalrate_2021', 'TENURECOST_clusterbar_geocomparative_rentalrate_overtime', 
           'TENURECOST_table_geocomparative_tenureandchange_overtime', 'TENURECOST_table_primarygeo_tenurebyraceandethnicity_overtime', 
           'TENURECOST_table_primarygeo_tenureandchangebyagegroup_overtime', 'TENURECOST_bar_primarygeo_mediangrossrent_overtime', 
           'TENURECOST_clusterbar_geocomparative_changemediangrossrent_overtime', 'TENURECOST_line_geocomparative_ZILLOWannualaveragerent_overtime', 
           'TENURECOST_clusterbar_geocomparative_ZILLOWpercentchangeannualaveragerent_overtime', 
           'TENURECOST_clusterbar_primarygeo_ownercostsbymortgagestatus_overtime', 
           'TENURECOST_clusterbar_geocomparative_changemedianownerwithmortgagecost_overtime', 'TENURECOST_bar_primarygeo_valueowneroccupiedhousing_overtime', 
           'TENURECOST_clusterbar_geocomparative_changemedianhomevalueowneroccupied_overtime', 
           'TENURECOST_line_geocomparative_ZILLOWannualhomevalueestimates_overtime', 'TENURECOST_bar_primarygeo_costburdenedhouseholds_overtime', 
           'TENURECOST_bar_primarygeo_sharehouseholdscostburdened_overtime', 'TENURECOST_bar_primarygeo_costburdenedownerocchouseholds_overtime', 
           'TENURECOST_bar_primarygeo_shareownerocchouseholdscostburdened_overtime', 'TENURECOST_bar_primarygeo_costburdenedrenterocchouseholds_overtime', 
           'TENURECOST_bar_primarygeo_sharerenterocchouseholdscostburdened_overtime', 'TENURECOST_stackedbar_geocomparative_costburdenbytenure_2021', 
           'TENURECOST_stackedbar_geocomparative_severecostburdenbytenure_2021', 'TENURECOST_table_primarygeo_allcostburdennumberandpercent_overtime', 
           'TENURECOST_clusterbar_primarygeo_allcostburdenpercentchange_overtime', 'TENURECOST_clusterbar_primarygeo_allcostburdenrealchange_overtime', 
           'TENURECOST_clusterbar_geocomparative_CNThtpercentofincome_2019', 'TENURECOST_stackedbar_geocomparative_CNThousingplustransportationcosts_2019', 
           'TENURECOST_table_geocomparative_CNThousingandtransportation_2019']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/TENURECOST/{}.png'.format(fig))
    with open('../Figures/TENURECOST/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Education Images Native Size
doc.add_heading('Education', 1)
thelist = ['EDUCATION_stackedbar_primarygeo_highestattainment_overtime', 'EDUCATION_table_primarygeo_attainmentnumberandpercent_overtime', 
           'EDUCATION_stackedbar_geocomparative_highestattainment_2021', 'EDUCATION_table_geocomparative_attainment_2021', 
           'EDUCATION_bar_primarygeo_highschoolandabove_overtime', 'EDUCATION_bar_primarygeo_sharehighschoolandabove_overtime', 
           'EDUCATION_bar_geocomparative_highschoolorhigherattainment_2021', 'EDUCATION_bar_primarygeo_bachelorsandabove_overtime', 
           'EDUCATION_bar_primarygeo_sharebachelorsandabove_overtime', 'EDUCATION_bar_geocomparative_bachelorsorhigherattainment_2021']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/EDUCATION/{}.png'.format(fig))
    with open('../Figures/EDUCATION/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
        
#Employment and Economy Images Native Size
doc.add_heading('Employment and Economy', 1)
with open('../Figures/EMP/EMP_text_primarygeo_liveandworkinprimarygeo_2019.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
with open('../Figures/EMP/EMP_text_primarygeo_liveinplaceworkincounty_2019.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
with open('../Figures/EMP/EMP_text_primarygeo_liveinprimarygeoandworkinregion_2019.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
thelist = ['EMP_bar_primarygeo_numindustryemployment_2021', 
           'EMP_bar_primarygeo_shareindustryemployment_2021', 'EMP_clusterbar_primarygeo_realchangeindustryemployment_overtime', 
           'EMP_clusterbar_primarygeo_percentchangeindustryemployment_overtime', 'EMP_table_primarygeo_industryemployment_overtime', 
           'EMP_pyramid_primarygeo_powporemploymentpyramid_2019', 'EMP_table_geocomparative_topemploymentcounties_2019', 
           'EMP_table_geocomparative_topemploymentcountiesage_2019', 'EMP_table_geocomparative_topemploymentcountiessupersector_2019', 
           'EMP_table_geocomparative_topemploymentplaces_2019', 'EMP_table_geocomparative_topemploymentplacesage_2019', 
           'EMP_table_geocomparative_topemploymentplacessupersector_2019', 'EMP_line_primarygeo_historicalemploymentplace_overtime', 
           'EMP_line_primarygeo_historicalemploymentbyindustryplace_overtime', 
           'EMP_stackedbar_primarygeo_supersectoremploymentplace_overtime', 
           'EMP_line_primarygeo_employmentquarterlycovid19_overtime', 'EMP_line_county_employmentquarterlycovid19countyforplace_overtime', 
           'EMP_line_geocomparative_unemploymentmonthly_overtime', 'EMP_table_primarygeo_industryemploymentplace_2020', 
           'EMP_bar_primarygeo_projectedemployment_overtime', 
           'EMP_bar_primarygeo_percentchangeprojectedemployment_overtime', 'EMP_bar_geocomparative_projectedemploymentchange_overtime', 
           'EMP_table_geocomparative_employmentprojectionandchange_overtime', 'EMP_table_primarygeo_industryemploymentoutlook_2022Q3', 
           'EMP_table_primarygeo_topcountyemployers_current', 'EMP_stackedbar_primarygeo_classofworker_overtime', 
           'EMP_bar_primarygeo_numoccupationalemployment_2021', 'EMP_bar_primarygeo_shareoccupationalemployment_2021', 
           'EMP_clusterbar_primarygeo_realchangeoccupationalemployment_overtime', 'EMP_clusterbar_primarygeo_percentchangeOccupationalemployment_overtime', 
           'EMP_table_primarygeo_occupationalemployment_overtime', 'EMP_line_primarygeo_historicalemploymentbyoccupation_overtime', 
           'EMP_table_primarygeo_occupationalemploymentoutlook_2022Q3', 'EMP_line_county_awardsgranted_overtime',
           'EMP_line_geocomparative_topcountiesedawards_overtime', 'EMP_line_geocomparative_allawardscounties_overtime', 'EMP_bar_primarygeo_numlfstatus_2021', 
           'EMP_bar_primarygeo_percentlfstatus_2021', 'EMP_clusterbar_primarygeo_realchangelfstatus_overtime', 
           'EMP_clusterbar_primarygeo_percentchangelfstatus_overtime', 'EMP_stackedbar_primarygeo_lfparticipation_overtime', 
           'EMP_stackedbar_primarygeo_civilianemploymentstatus_overtime', 'EMP_line_geocomparative_unemploymentcounties_overtime', 
           'EMP_bar_geocomparative_civilianunemploymentrate_2021', 'EMP_bar_primarygeo_medianannualearningsallworkers_overtime', 
           'EMP_bar_primarygeo_medianannualearningsfulltimeworkers_overtime', 'EMP_bar_primarygeo_medianearningsallworkerscount_2021', 
           'EMP_bar_primarygeo_medianearningsdistributionallworkers_2021', 'EMP_bar_primarygeo_medianearningsfulltimeworkerscount_2021', 
           'EMP_bar_primarygeo_medianearningsdistributionfulltimeworkers_2021', 'EMP_bar_geocomparative_medianannualearningsfulltimeworkers_2021', 
           'EMP_bar_primarygeo_medianannualearningsraceethallworkers_2021', 'EMP_bar_primarygeo_percapitaincome_overtime', 
           'EMP_bar_geocomparative_percapitaincome_2021', 'EMP_line_primarygeo_gdpcounty_overtime', 'EMP_line_geocomparative_gdpcounties_overtime', 
           'EMP_line_primarygeo_gdpcountydavidson_overtime']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/EMP/{}.png'.format(fig))
    with open('../Figures/EMP/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Transportation Images Native Size
doc.add_heading('Transportation', 1)
thelist = ['TRANSPO_table_geocomparative_totalcrashes_overtime', 'TRANSPO_table_primarygeo_fatalcrashes_overtime', 
           'TRANSPO_table_primarygeo_seriousinjurycrashes_overtime', 'TRANSPO_line_geocomparative_totalcrashes_overtime', 
           'TRANSPO_line_geocomparative_fatalcrashes_overtime', 'TRANSPO_line_geocomparative_percentfatalcrashes_overtime', 
           'TRANSPO_line_geocomparative_seriousinjurycrashes_overtime', 'TRANSPO_line_geocomparative_percentseriousinjurycrashes_overtime', 
           'TRANSPO_bar_primarygeo_meansoftransportationtowork_2021', 'TRANSPO_bar_primarygeo_sharemeansoftransportationtowork_2021', 
           'TRANSPO_stackedbar_primarygeo_sharecommutemodes_overtime', 'TRANSPO_stackedbar_geocomparative_sharecommutemodes_2021', 
           'TRANSPO_line_geocomparative_commutetime_overtime', 'TRANSPO_bar_primarygeo_extremelylongcommutetime_overtime', 
           'TRANSPO_line_geocomparative_extremelylongcommutetime_overtime', 'TRANSPO_bar_primarygeo_workfromhome_overtime', 
           'TRANSPO_line_geocomparative_shareworkfromhome_overtime', 'TRANSPO_bar_primarygeo_novehicleavailable_overtime', 
           'TRANSPO_line_geocomparative_novehicleavailable_overtime']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/TRANSPO/{}.png'.format(fig))
    with open('../Figures/TRANSPO/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Health Images Native Size
doc.add_heading('Health', 1)
thelist = ['HEALTH_bar_geocomparative_sharepopulationnohealthcoverage_2021', 'HEALTH_stackedbar_geocomparative_sharewithandwithouthealthcarecoverage_2021', 
           'HEALTH_clusterbar_geocomparative_publicandprivatehealthinsurancecoverage_2021', 'HEALTH_table_geocomparative_healthinsurancebytype_2021', 
           'HEALTH_bar_geocomparative_countyhealthoutcomes_2022', 'HEALTH_bar_geocomparative_countyhealthfactors_2022', 
           'HEALTH_bar_geocomparative_countyaveragelifeexpectancy_2022', 'HEALTH_bar_geocomparative_frequentphysicaldistress_2022', 
           'HEALTH_bar_geocomparative_frequentmentaldistress_2022']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/HEALTH/{}.png'.format(fig))
    with open('../Figures/HEALTH/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)
            
#Crime Images Native Size
doc.add_heading('Crime', 1)
thelist = ['CRIME_bar_geocomparative_crimerate_2021', 'CRIME_bar_geocomparative_crimecount_2021', 'CRIME_bar_primarygeo_crimetype_2021']  
for fig in thelist:
    doc.add_heading('{}:'.format(fig), 3)
    doc.add_picture('../Figures/CRIME/{}.png'.format(fig))
    with open('../Figures/CRIME/{}.txt'.format(fig)) as f:
        for line in f:
            doc.add_paragraph(line)

# Now save the document to a location
doc.save('Portland Figures.docx')
